# %% [markdown]
# El primer problema que plantea el libro es el siguiente:
#
# 1. $$\frac{(152 \frac{3}{4} - 148 \frac{3}{8}) \cdot0,3}{0,2}$$

# %%
#Para resolver este problema resolveremos dividiendo la divición
top = ((((152*4)+3)/4) - (((148*8)+3)/8)) * 0.3
bottom = 0.2
result = top / bottom
print(result)
# Out:
# 6.5625

# %% [markdown]
# El resultado proporcionado por el libro es:
# $$ 6,5625 $$
